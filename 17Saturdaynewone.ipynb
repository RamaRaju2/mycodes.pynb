# %%
# afternoon(saturday)-17/03/2023
#rainfall in india

# %%
import pandas as pd

# %%
data=pd.read_csv("/home/placement/Desktop/ramaraju/rainfall in india 1901-2015.csv")

# %%
data
# Out:
#                     SUBDIVISION  YEAR   JAN    FEB   MAR    APR    MAY    JUN  \
# 0     ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1  29.2    2.3  528.8  517.5
# 1     ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8  12.2    0.0  446.1  537.1
# 2     ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0   0.0    1.0  235.1  479.9
# 3     ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7   0.0  202.4  304.5  495.1
# 4     ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0   3.3   26.9  279.5  628.7
# ...                         ...   ...   ...    ...   ...    ...    ...    ...
# 4111                LAKSHADWEEP  2011   5.1    2.8   3.1   85.9  107.2  153.6
# 4112                LAKSHADWEEP  2012  19.2    0.1   1.6   76.8   21.2  327.0
# 4113                LAKSHADWEEP  2013  26.2   34.4  37.5    5.3   88.3  426.2
# 4114                LAKSHADWEEP  2014  53.2   16.1   4.4   14.9   57.4  244.1
# 4115                LAKSHADWEEP  2015   2.2    0.5   3.7   87.1  133.1  296.6
#
# ...

# %%
data.describe()
# Out:
#               YEAR          JAN          FEB          MAR          APR  \
# count  4116.000000  4112.000000  4113.000000  4110.000000  4112.000000
# mean   1958.218659    18.957320    21.805325    27.359197    43.127432
# std      33.140898    33.585371    35.909488    46.959424    67.831168
# min    1901.000000     0.000000     0.000000     0.000000     0.000000
# 25%    1930.000000     0.600000     0.600000     1.000000     3.000000
# 50%    1958.000000     6.000000     6.700000     7.800000    15.700000
# 75%    1987.000000    22.200000    26.800000    31.300000    49.950000
# max    2015.000000   583.700000   403.500000   605.600000   595.100000
#
#                MAY          JUN          JUL          AUG          SEP  \
# count  4113.000000  4111.000000  4109.000000  4112.000000  4110.000000
# mean     85.745417   230.234444   347.214334   290.263497   197.361922
# std     123.234904   234.710758   269.539667   188.770477   135.408345
# ...

# %%
list(data)
# Out:
# ['SUBDIVISION',
#  'YEAR',
#  'JAN',
#  'FEB',
#  'MAR',
#  'APR',
#  'MAY',
#  'JUN',
#  'JUL',
#  'AUG',
#  'SEP',
#  'OCT',
#  'NOV',
#  'DEC',
#  'ANNUAL',
#  'Jan-Feb',
#  'Mar-May',
#  'Jun-Sep',
#  'Oct-Dec']

# %%
data1=data.groupby(['SUBDIVISION']).count()

# %%
data1
# Out:
#                                     YEAR  JAN  FEB  MAR  APR  MAY  JUN  JUL  \
# SUBDIVISION
# ANDAMAN & NICOBAR ISLANDS            110  110  110  108  108  109  108  108
# ARUNACHAL PRADESH                     97   96   96   95   97   97   96   96
# ASSAM & MEGHALAYA                    115  115  115  115  115  115  115  115
# BIHAR                                115  115  115  115  115  115  115  115
# CHHATTISGARH                         115  115  115  115  115  115  115  115
# COASTAL ANDHRA PRADESH               115  115  115  115  115  115  115  115
# COASTAL KARNATAKA                    115  114  115  115  115  115  115  115
# EAST MADHYA PRADESH                  115  115  115  115  115  115  115  115
# EAST RAJASTHAN                       115  115  115  115  115  115  115  115
# EAST UTTAR PRADESH                   115  115  115  115  115  115  115  115
# GANGETIC WEST BENGAL                 115  115  115  115  115  115  115  115
# ...

# %%
data.shape
# Out:
# (4116, 19)

# %%
#CHECKING STATEMENT FOR NULL VALUES
data.isna().sum()
# Out:
# SUBDIVISION     0
# YEAR            0
# JAN             4
# FEB             3
# MAR             6
# APR             4
# MAY             3
# JUN             5
# JUL             7
# AUG             4
# SEP             6
# OCT             7
# NOV            11
# DEC            10
# ANNUAL         26
# Jan-Feb         6
# Mar-May         9
# Jun-Sep        10
# Oct-Dec        13
# dtype: int64

# %%
#i want data upto 2010,so we have to locate the data
data1=data.loc[(data.YEAR<=2010)]
data1
# Out:
#                     SUBDIVISION  YEAR   JAN    FEB    MAR    APR    MAY  \
# 0     ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1   29.2    2.3  528.8
# 1     ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8   12.2    0.0  446.1
# 2     ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0    0.0    1.0  235.1
# 3     ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7    0.0  202.4  304.5
# 4     ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0    3.3   26.9  279.5
# ...                         ...   ...   ...    ...    ...    ...    ...
# 4106                LAKSHADWEEP  2006  20.1    0.0   33.0    0.3  327.9
# 4107                LAKSHADWEEP  2007   2.5    4.2    0.2   22.2  166.2
# 4108                LAKSHADWEEP  2008   5.5   19.8  120.7   15.8  180.4
# 4109                LAKSHADWEEP  2009   4.7    1.5    0.1   18.1  162.1
# 4110                LAKSHADWEEP  2010  18.8    0.0    1.2   35.6   79.0
#
#         JUN    JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  Jan-Feb  \
# ...

# %%
data1.tail()
# Out:
#       SUBDIVISION  YEAR   JAN   FEB    MAR   APR    MAY    JUN    JUL    AUG  \
# 4106  LAKSHADWEEP  2006  20.1   0.0   33.0   0.3  327.9  286.9  172.3  150.7
# 4107  LAKSHADWEEP  2007   2.5   4.2    0.2  22.2  166.2  573.4  427.4  294.7
# 4108  LAKSHADWEEP  2008   5.5  19.8  120.7  15.8  180.4  254.6  363.9  206.6
# 4109  LAKSHADWEEP  2009   4.7   1.5    0.1  18.1  162.1  401.2  266.4  185.0
# 4110  LAKSHADWEEP  2010  18.8   0.0    1.2  35.6   79.0  318.9  336.7  335.1
#
#         SEP    OCT    NOV    DEC  ANNUAL  Jan-Feb  Mar-May  Jun-Sep  Oct-Dec
# 4106  318.5  119.1  158.9   10.9  1598.6     20.1    361.2    928.4    288.9
# 4107  457.5  256.1   47.6  109.6  2361.6      6.7    188.6   1753.0    413.3
# 4108  108.9  252.9   67.6  130.1  1726.8     25.3    316.9    934.0    450.6
# 4109  145.1   87.4  166.2  132.3  1570.1      6.2    180.3    997.7    385.9
# 4110  161.5  155.4  201.5   81.5  1725.2     18.8    115.8   1152.2    438.4

# %%
data1.drop(["ANNUAL","Jan-Feb","Mar-May","Jun-Sep","Oct-Dec"],axis=1)
# Out:
#                     SUBDIVISION  YEAR   JAN    FEB    MAR    APR    MAY  \
# 0     ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1   29.2    2.3  528.8
# 1     ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8   12.2    0.0  446.1
# 2     ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0    0.0    1.0  235.1
# 3     ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7    0.0  202.4  304.5
# 4     ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0    3.3   26.9  279.5
# ...                         ...   ...   ...    ...    ...    ...    ...
# 4106                LAKSHADWEEP  2006  20.1    0.0   33.0    0.3  327.9
# 4107                LAKSHADWEEP  2007   2.5    4.2    0.2   22.2  166.2
# 4108                LAKSHADWEEP  2008   5.5   19.8  120.7   15.8  180.4
# 4109                LAKSHADWEEP  2009   4.7    1.5    0.1   18.1  162.1
# 4110                LAKSHADWEEP  2010  18.8    0.0    1.2   35.6   79.0
#
#         JUN    JUL    AUG    SEP    OCT    NOV    DEC
# ...

# %%
data1['SUBDIVISION'].unique()
# Out:
# array(['ANDAMAN & NICOBAR ISLANDS', 'ARUNACHAL PRADESH',
#        'ASSAM & MEGHALAYA', 'NAGA MANI MIZO TRIPURA',
#        'SUB HIMALAYAN WEST BENGAL & SIKKIM', 'GANGETIC WEST BENGAL',
#        'ORISSA', 'JHARKHAND', 'BIHAR', 'EAST UTTAR PRADESH',
#        'WEST UTTAR PRADESH', 'UTTARAKHAND', 'HARYANA DELHI & CHANDIGARH',
#        'PUNJAB', 'HIMACHAL PRADESH', 'JAMMU & KASHMIR', 'WEST RAJASTHAN',
#        'EAST RAJASTHAN', 'WEST MADHYA PRADESH', 'EAST MADHYA PRADESH',
#        'GUJARAT REGION', 'SAURASHTRA & KUTCH', 'KONKAN & GOA',
#        'MADHYA MAHARASHTRA', 'MATATHWADA', 'VIDARBHA', 'CHHATTISGARH',
#        'COASTAL ANDHRA PRADESH', 'TELANGANA', 'RAYALSEEMA', 'TAMIL NADU',
#        'COASTAL KARNATAKA', 'NORTH INTERIOR KARNATAKA',
#        'SOUTH INTERIOR KARNATAKA', 'KERALA', 'LAKSHADWEEP'], dtype=object)

# %%
#extracting only for the coastal andhra pradesh
data2=data1.loc[(data1.SUBDIVISION =='COASTAL ANDHRA PRADESH')]

# %%
data2.isna().sum()
# Out:
# SUBDIVISION    0
# YEAR           0
# JAN            0
# FEB            0
# MAR            0
# APR            0
# MAY            0
# JUN            0
# JUL            0
# AUG            0
# SEP            0
# OCT            0
# NOV            0
# DEC            0
# ANNUAL         0
# Jan-Feb        0
# Mar-May        0
# Jun-Sep        0
# Oct-Dec        0
# dtype: int64

# %%
#how can you add two columns in a data frame.
data2['ANNUAL RAIN']=data2.apply(lambda row: row.JAN + row.FEB + row.MAR + row.APR + row.MAY + row.JUN + row.JUL + row.AUG + row.SEP + row.OCT + row.NOV + row.DEC,axis=1)
# Out:
# /tmp/ipykernel_6196/1238812419.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2['ANNUAL RAIN']=data2.apply(lambda row: row.JAN + row.FEB + row.MAR + row.APR + row.MAY + row.JUN + row.JUL + row.AUG + row.SEP + row.OCT + row.NOV + row.DEC,axis=1)

# %%
#data name should be same 
#data2["ANNUAL YEAR"]=data2.apply(lambda row:row.JAN+row.FEB,axis=1)

# %%
#list(data2)
data2.head()
# Out:
#                  SUBDIVISION  YEAR   JAN   FEB   MAR   APR    MAY    JUN  \
# 3082  COASTAL ANDHRA PRADESH  1901  18.8  80.9   7.2  28.7   68.7   77.7
# 3083  COASTAL ANDHRA PRADESH  1902   2.0   0.0   2.8  23.9   37.6   72.6
# 3084  COASTAL ANDHRA PRADESH  1903   0.8  13.3   0.2   6.2   73.4  154.0
# 3085  COASTAL ANDHRA PRADESH  1904   1.3   0.0   5.4   3.0  136.3  107.8
# 3086  COASTAL ANDHRA PRADESH  1905   1.1  16.7  68.0  37.0   68.8   84.4
#
#         JUL    AUG    SEP    OCT    NOV   DEC  ANNUAL  Jan-Feb  Mar-May  \
# 3082  113.0  133.7  125.3  173.4  164.8   1.5   993.8     99.7    104.6
# 3083  144.5  236.1  204.5  262.0   50.4  27.1  1063.6      2.0     64.4
# 3084  248.6  258.0  216.5  159.1  173.9  12.1  1316.2     14.2     79.8
# 3085  120.2  117.7  116.8  240.9    0.0  10.7   860.2      1.3    144.7
# 3086   64.6  210.8  170.2   66.0    7.4   0.0   795.2     17.8    173.8
#
#       Jun-Sep  Oct-Dec  ANNUAL RAIN
# 3082    449.7    339.8        993.7
# ...

# %%
#data2["ANNUAL RAIN"]=data2.apply(lambda row:row.JAN+row.FEB,JANAPRMAYJUNJULAUGOCTNOVDECaxis=1)

# %%
cor=data1.corr()
cor
# Out:
# /tmp/ipykernel_6196/870474124.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cor=data1.corr()
#              YEAR       JAN       FEB       MAR       APR       MAY       JUN  \
# YEAR     1.000000 -0.058347 -0.025395  0.021270  0.003352  0.011466 -0.011423
# JAN     -0.058347  1.000000  0.455269  0.394644  0.209324  0.125105 -0.036012
# FEB     -0.025395  0.455269  1.000000  0.579953  0.375937  0.208097  0.034770
# MAR      0.021270  0.394644  0.579953  1.000000  0.561032  0.365496  0.169123
# APR      0.003352  0.209324  0.375937  0.561032  1.000000  0.654756  0.459424
# MAY      0.011466  0.125105  0.208097  0.365496  0.654756  1.000000  0.571782
# JUN     -0.011423 -0.036012  0.034770  0.169123  0.459424  0.571782  1.000000
# JUL     -0.006981 -0.053761  0.018933  0.100336  0.273724  0.336364  0.740562
# ...

# %%
import seaborn as sns
sns.heatmap(cor,vmax=1,vmin=-1,annot=True,linewidths=.5,cmap='bwr')
# Out:
# <Axes: >

# %%
#SOUTH WEST MONSOON
data2["SWM"]=data2.apply(lambda row:row.JUN+row.JUL+row.AUG+row.SEP,axis=1)
data2
# Out:
# /tmp/ipykernel_6196/764677443.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2["SWM"]=data2.apply(lambda row:row.JUN+row.JUL+row.AUG+row.SEP,axis=1)
#                  SUBDIVISION  YEAR   JAN   FEB   MAR   APR    MAY    JUN  \
# 3082  COASTAL ANDHRA PRADESH  1901  18.8  80.9   7.2  28.7   68.7   77.7
# 3083  COASTAL ANDHRA PRADESH  1902   2.0   0.0   2.8  23.9   37.6   72.6
# 3084  COASTAL ANDHRA PRADESH  1903   0.8  13.3   0.2   6.2   73.4  154.0
# 3085  COASTAL ANDHRA PRADESH  1904   1.3   0.0   5.4   3.0  136.3  107.8
# 3086  COASTAL ANDHRA PRADESH  1905   1.1  16.7  68.0  37.0   68.8   84.4
# ...                      ...   ...   ...   ...   ...   ...    ...    ...
# ...

# %%
data2["NEM"]=data2.apply(lambda row:row.OCT+row.NOV+row.DEC,axis=1)
data2
# Out:
# /tmp/ipykernel_6196/1538856487.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2["NEM"]=data2.apply(lambda row:row.OCT+row.NOV+row.DEC,axis=1)
#                  SUBDIVISION  YEAR   JAN   FEB   MAR   APR    MAY    JUN  \
# 3082  COASTAL ANDHRA PRADESH  1901  18.8  80.9   7.2  28.7   68.7   77.7
# 3083  COASTAL ANDHRA PRADESH  1902   2.0   0.0   2.8  23.9   37.6   72.6
# 3084  COASTAL ANDHRA PRADESH  1903   0.8  13.3   0.2   6.2   73.4  154.0
# 3085  COASTAL ANDHRA PRADESH  1904   1.3   0.0   5.4   3.0  136.3  107.8
# 3086  COASTAL ANDHRA PRADESH  1905   1.1  16.7  68.0  37.0   68.8   84.4
# ...                      ...   ...   ...   ...   ...   ...    ...    ...
# ...

# %%
data2.drop(["SUBDIVISION","YEAR","JAN","FEB","MAR","APR","MAY","JUN","JUL","AUG","NOV","DEC","ANNUAL","Jan-Feb","Mar-May","Jun-Sep","Oct-Dec"],axis=1)
data2
# Out:
#                  SUBDIVISION  YEAR   JAN   FEB   MAR   APR    MAY    JUN  \
# 3082  COASTAL ANDHRA PRADESH  1901  18.8  80.9   7.2  28.7   68.7   77.7
# 3083  COASTAL ANDHRA PRADESH  1902   2.0   0.0   2.8  23.9   37.6   72.6
# 3084  COASTAL ANDHRA PRADESH  1903   0.8  13.3   0.2   6.2   73.4  154.0
# 3085  COASTAL ANDHRA PRADESH  1904   1.3   0.0   5.4   3.0  136.3  107.8
# 3086  COASTAL ANDHRA PRADESH  1905   1.1  16.7  68.0  37.0   68.8   84.4
# ...                      ...   ...   ...   ...   ...   ...    ...    ...
# 3187  COASTAL ANDHRA PRADESH  2006   0.0   0.0  30.7  58.0   67.6  132.0
# 3188  COASTAL ANDHRA PRADESH  2007   0.0   5.1   0.1   8.5   13.0  300.1
# 3189  COASTAL ANDHRA PRADESH  2008   3.2  61.6  93.8  18.5   34.9  119.8
# 3190  COASTAL ANDHRA PRADESH  2009   0.0   0.0   5.7   6.4   53.0   72.6
# 3191  COASTAL ANDHRA PRADESH  2010  21.8   2.3   4.4  14.8  162.0  156.1
#
#         JUL    AUG  ...    NOV    DEC  ANNUAL  Jan-Feb  Mar-May  Jun-Sep  \
# ...

# %%
cor=data2.corr()
cor
# Out:
# /tmp/ipykernel_6196/3832707278.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cor=data2.corr()
#                  YEAR       JAN       FEB       MAR       APR       MAY  \
# YEAR         1.000000  0.047547 -0.066570  0.072356 -0.051745  0.060743
# JAN          0.047547  1.000000 -0.050667 -0.017227 -0.056167 -0.017362
# FEB         -0.066570 -0.050667  1.000000  0.175467  0.037707  0.259281
# MAR          0.072356 -0.017227  0.175467  1.000000  0.076668  0.220876
# APR         -0.051745 -0.056167  0.037707  0.076668  1.000000 -0.056924
# MAY          0.060743 -0.017362  0.259281  0.220876 -0.056924  1.000000
# JUN          0.001861 -0.148576  0.005251 -0.042490 -0.145100 -0.029637
# JUL          0.157812 -0.009395 -0.127934 -0.031517 -0.133836 -0.093448
# ...

# %%
import seaborn as sns
sns.heatmap(cor,vmax=1,vmin=-1,annot=True,linewidths=.5,cmap='bwr')
# Out:
# <Axes: >
